# %% [markdown]
# ## Title:  Discussion on the ethical concerns of COMPASS

# %% [markdown]
# # Content of the document
#  1. Problem Statement
#  2. Data Collection
#  3. Data Preparation
#  4. Data Preprocessing
#  5. Model Assessement (Fairness) & optimization
#  7. Conclusion
#  8. References

# %% [markdown]
# # 1. Problem Statement
#
# We are investigating COMPAS, a popular commercial algorithm for predicting reoffending likelihoods (recidivism) for criminal defendants. There has been evidence that the algorithm is biased towards white defendants and against black inmates. Next, use a fairness approach to improve the model.
#
# In order to accomplish this, I need first to explore the data and prepare it, then assess the fairness, then use one of the approaches to optimize it

# %% [markdown]
# Here are the steps I will take in this project:
#
#      1. Data Collection
#      2. Data Exploration: This will be done to identify the most important features and combine them in new ways.
#      3. Data Preprocessing: Lay out a pipeline of tasks for transforming data for use in my machine learning model.
#      4. Model Assessment: Determine the type of descrimination.
#      6. How to improve the fairness
#      7. Conclusion & recommendations

# %% [markdown]
# # 2. Data Collection
#
# In this step I do two things:
#
#   - Identify data sources
#   - Split the data into training and test sets
#
#
# Before starting, as a first step, I will call some libraries I need in order to build my model.

# %%
# Libraries 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import set_matplotlib_formats
# %matplotlib inline
import os
import warnings
from sklearn.model_selection import StratifiedShuffleSplit
warnings.filterwarnings("ignore")
from sklearn.datasets import make_regression, make_classification, make_blobs
import sklearn.model_selection
import sklearn.linear_model

# %% [markdown]
# #### Source of the data: (kaggle.com, n.d.)

# %%
# Load the data from Kaggle Repository
initial_data = pd.read_csv('cox-violent-parsed.csv')

# Examine date structure and return the top 5 rows of the data frame.
initial_data.head(5)
# Out:
#     id              name    first       last compas_screening_date   sex  \
# 0  1.0  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 1  2.0  miguel hernandez   miguel  hernandez            14/08/2013  Male
# 2  3.0      michael ryan  michael       ryan            31/12/2014  Male
# 3  4.0       kevon dixon    kevon      dixon            27/01/2013  Male
# 4  5.0          ed philo       ed      philo            14/04/2013  Male
#
#           dob  age          age_cat              race  ...  \
# 0  18/04/1947   69  Greater than 45             Other  ...
# 1  18/04/1947   69  Greater than 45             Other  ...
# 2  06/02/1985   31          25 - 45         Caucasian  ...
# 3  22/01/1982   34          25 - 45  African-American  ...
# 4  14/05/1991   24     Less than 25  African-American  ...
#
#    v_type_of_assessment  v_decile_score  v_score_text  v_screening_date  \
# 0      Risk of Violence               1           Low        14/08/2013
# 1      Risk of Violence               1           Low        14/08/2013
# 2      Risk of Violence               2           Low        31/12/2014
# 3      Risk of Violence               1           Low        27/01/2013
# 4      Risk of Violence               3           Low        14/04/2013
#
#    in_custody  out_custody priors_count.1 start  end event
# 0  07/07/2014   14/07/2014              0     0  327     0
# 1  07/07/2014   14/07/2014              0   334  961     0
# 2  30/12/2014   03/01/2015              0     3  457     0
# 3  26/01/2013   05/02/2013              0     9  159     1
# 4  16/06/2013   16/06/2013              4     0   63     0
#
# [5 rows x 52 columns]

# %% [markdown]
# In the table above, the date columns are displayed in object format

# %%
# Convert date columns from object format to time format

# attributes is the list of columns to be converted
attributes= ["in_custody","out_custody","v_screening_date","compas_screening_date", "dob","c_jail_in","c_jail_out","c_offense_date",
             "screening_date","vr_offense_date","r_jail_out","r_jail_in","r_offense_date","c_arrest_date"]

initial_data = pd.read_csv('cox-violent-parsed.csv',parse_dates=attributes)

# Create a copy of the original data
my_data = initial_data.copy()

# Examine my data structure and return the top 5 rows of the data frame.
my_data.head(5)
# Out:
#     id              name    first       last compas_screening_date   sex  \
# 0  1.0  miguel hernandez   miguel  hernandez            2013-08-14  Male
# 1  2.0  miguel hernandez   miguel  hernandez            2013-08-14  Male
# 2  3.0      michael ryan  michael       ryan            2014-12-31  Male
# 3  4.0       kevon dixon    kevon      dixon            2013-01-27  Male
# 4  5.0          ed philo       ed      philo            2013-04-14  Male
#
#          dob  age          age_cat              race  ...  \
# 0 1947-04-18   69  Greater than 45             Other  ...
# 1 1947-04-18   69  Greater than 45             Other  ...
# 2 1985-06-02   31          25 - 45         Caucasian  ...
# 3 1982-01-22   34          25 - 45  African-American  ...
# 4 1991-05-14   24     Less than 25  African-American  ...
#
#    v_type_of_assessment  v_decile_score  v_score_text  v_screening_date  \
# 0      Risk of Violence               1           Low        2013-08-14
# 1      Risk of Violence               1           Low        2013-08-14
# 2      Risk of Violence               2           Low        2014-12-31
# 3      Risk of Violence               1           Low        2013-01-27
# 4      Risk of Violence               3           Low        2013-04-14
#
#    in_custody  out_custody priors_count.1 start  end event
# 0  2014-07-07   2014-07-14              0     0  327     0
# 1  2014-07-07   2014-07-14              0   334  961     0
# 2  2014-12-30   2015-03-01              0     3  457     0
# 3  2013-01-26   2013-05-02              0     9  159     1
# 4  2013-06-16   2013-06-16              4     0   63     0
#
# [5 rows x 52 columns]

# %%
#Check the type data of my attributes
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18316 entries, 0 to 18315
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       11001 non-null  float64
#  1   name                     18316 non-null  object
#  2   first                    18316 non-null  object
#  3   last                     18316 non-null  object
#  4   compas_screening_date    18316 non-null  datetime64[ns]
#  5   sex                      18316 non-null  object
#  6   dob                      18316 non-null  datetime64[ns]
#  7   age                      18316 non-null  int64
#  8   age_cat                  18316 non-null  object
#  9   race                     18316 non-null  object
#  10  juv_fel_count            18316 non-null  int64
#  11  decile_score             18316 non-null  int64
#  12  juv_misd_count           18316 non-null  int64
#  13  juv_other_count          18316 non-null  int64
#  14  priors_count             18316 non-null  int64
#  15  days_b_screening_arrest  17019 non-null  float64
#  16  c_jail_in                17019 non-null  datetime64[ns]
#  17  c_jail_out               17019 non-null  datetime64[ns]
#  18  c_case_number            17449 non-null  object
#  19  c_offense_date           14364 non-null  datetime64[ns]
#  20  c_arrest_date            3085 non-null   datetime64[ns]
#  21  c_days_from_compas       17449 non-null  float64
#  22  c_charge_degree          17449 non-null  object
#  23  c_charge_desc            17435 non-null  object
#  24  is_recid                 18316 non-null  int64
#  25  r_case_number            8417 non-null   object
#  26  r_charge_degree          8417 non-null   object
#  27  r_days_from_arrest       6359 non-null   float64
#  28  r_offense_date           8417 non-null   datetime64[ns]
#  29  r_charge_desc            8277 non-null   object
#  30  r_jail_in                6359 non-null   datetime64[ns]
#  31  r_jail_out               6359 non-null   datetime64[ns]
#  32  violent_recid            0 non-null      float64
#  33  is_violent_recid         18316 non-null  int64
#  34  vr_case_number           1339 non-null   object
#  35  vr_charge_degree         1339 non-null   object
#  36  vr_offense_date          1339 non-null   datetime64[ns]
#  37  vr_charge_desc           1339 non-null   object
#  38  type_of_assessment       18316 non-null  object
#  39  decile_score.1           18316 non-null  int64
#  40  score_text               18293 non-null  object
#  41  screening_date           18316 non-null  datetime64[ns]
#  42  v_type_of_assessment     18316 non-null  object
#  43  v_decile_score           18316 non-null  int64
#  44  v_score_text             18310 non-null  object
#  45  v_screening_date         18316 non-null  datetime64[ns]
#  46  in_custody               17722 non-null  datetime64[ns]
#  47  out_custody              17722 non-null  datetime64[ns]
#  48  priors_count.1           18316 non-null  int64
#  49  start                    18316 non-null  int64
#  50  end                      18316 non-null  int64
#  51  event                    18316 non-null  int64
# dtypes: datetime64[ns](14), float64(5), int64(14), object(19)
# memory usage: 7.3+ MB

# %%
#Check if there are null values in my dataset
my_data_not_nut = my_data.isnull().sum()
#display non null data
my_data_not_nut[my_data_not_nut>0]
# Out:
# id                          7315
# days_b_screening_arrest     1297
# c_jail_in                   1297
# c_jail_out                  1297
# c_case_number                867
# c_offense_date              3952
# c_arrest_date              15231
# c_days_from_compas           867
# c_charge_degree              867
# c_charge_desc                881
# r_case_number               9899
# r_charge_degree             9899
# r_days_from_arrest         11957
# r_offense_date              9899
# r_charge_desc              10039
# r_jail_in                  11957
# r_jail_out                 11957
# violent_recid              18316
# vr_case_number             16977
# vr_charge_degree           16977
# vr_offense_date            16977
# vr_charge_desc             16977
# score_text                    23
# v_score_text                   6
# in_custody                   594
# out_custody                  594
# dtype: int64

# %% [markdown]
# 48% (25 from 51) of the attributes has null values!

# %% [markdown]
# The dataset I have has 52 attributes, to make my analysis more efficient I will drop the unecessary ones to my study

# %%
#List of the attributes I am keeping
needed_attributes = ["id","name","dob","compas_screening_date","c_offense_date","sex","age","age_cat","race","c_charge_degree","c_charge_desc", 
"days_b_screening_arrest", "decile_score", "is_recid","r_offense_date", "c_case_number","v_decile_score", 
"is_violent_recid","vr_offense_date","score_text"] 

#Copy my data in a new variable, to keep the original one untouched
analysis = my_data.loc[:,needed_attributes].copy()
analysis
# Out:
#         id                   name        dob compas_screening_date  \
# 0      1.0       miguel hernandez 1947-04-18            2013-08-14
# 1      2.0       miguel hernandez 1947-04-18            2013-08-14
# 2      3.0           michael ryan 1985-06-02            2014-12-31
# 3      4.0            kevon dixon 1982-01-22            2013-01-27
# 4      5.0               ed philo 1991-05-14            2013-04-14
# ...    ...                    ...        ...                   ...
# 18311  NaN  alexsandra beauchamps 1984-12-21            2014-12-29
# 18312  NaN        winston gregory 1958-01-10            2014-01-14
# 18313  NaN            farrah jean 1982-11-17            2014-09-03
# 18314  NaN    florencia sanmartin 1992-12-18            2014-06-30
# 18315  NaN    florencia sanmartin 1992-12-18            2014-06-30
#
#       c_offense_date     sex  age          age_cat              race  \
# 0         2013-08-13    Male   69  Greater than 45             Other
# 1         2013-08-13    Male   69  Greater than 45             Other
# 2                NaT    Male   31          25 - 45         Caucasian
# 3         2013-01-26    Male   34          25 - 45  African-American
# 4         2013-04-13    Male   24     Less than 25  African-American
# ...              ...     ...  ...              ...               ...
# 18311     2014-12-28  Female   31          25 - 45  African-American
# 18312     2014-01-13    Male   57  Greater than 45             Other
# 18313     2014-08-03  Female   33          25 - 45  African-American
# 18314     2014-06-28  Female   23     Less than 25          Hispanic
# 18315     2014-06-28  Female   23     Less than 25          Hispanic
#
#       c_charge_degree                   c_charge_desc  \
# 0                (F3)    Aggravated Assault w/Firearm
# 1                (F3)    Aggravated Assault w/Firearm
# 2                 NaN                             NaN
# 3                (F3)  Felony Battery w/Prior Convict
# 4                (F3)           Possession of Cocaine
# ...               ...                             ...
# 18311            (M1)                         Battery
# 18312            (F2)   Aggravated Battery / Pregnant
# 18313            (M1)   Battery on Law Enforc Officer
# 18314            (F3)          Possession of Ethylone
# 18315            (F3)          Possession of Ethylone
#
#        days_b_screening_arrest  decile_score  is_recid r_offense_date  \
# 0                         -1.0             1         0            NaT
# 1                         -1.0             1         0            NaT
# 2                          NaN             5        -1            NaT
# 3                         -1.0             3         1     2013-05-07
# 4                         -1.0             4         1     2013-06-16
# ...                        ...           ...       ...            ...
# 18311                     -1.0             6         0            NaT
# 18312                     -1.0             1         0            NaT
# 18313                     -1.0             2         0            NaT
# 18314                     -2.0             4         1     2015-03-15
# 18315                     -2.0             4         1     2015-03-15
#
#        c_case_number  v_decile_score  is_violent_recid vr_offense_date  \
# 0      13011352CF10A               1                 0             NaT
# 1      13011352CF10A               1                 0             NaT
# 2                NaN               2                 0             NaT
# 3      13001275CF10A               1                 1      2013-05-07
# 4      13005330CF10A               3                 0             NaT
# ...              ...             ...               ...             ...
# 18311  14018106MM10A               4                 0             NaT
# 18312  14000581CF10A               1                 0             NaT
# 18313  14003308CF10A               2                 0             NaT
# 18314  14008895CF10A               4                 0             NaT
# 18315  14008895CF10A               4                 0             NaT
#
#       score_text
# 0            Low
# 1            Low
# 2         Medium
# 3            Low
# 4            Low
# ...          ...
# 18311     Medium
# 18312        Low
# 18313        Low
# 18314        Low
# 18315        Low
#
# [18316 rows x 20 columns]

# %%
# Check if my dataset has any duplicates for the same name

analysis.duplicated().sum()
analysis[analysis.duplicated(["name","age","sex","race","dob"],keep=False)]
# Out:
#         id                 name        dob compas_screening_date  \
# 0      1.0     miguel hernandez 1947-04-18            2013-08-14
# 1      2.0     miguel hernandez 1947-04-18            2013-08-14
# 4      5.0             ed philo 1991-05-14            2013-04-14
# 5      6.0             ed philo 1991-05-14            2013-04-14
# 6      7.0             ed philo 1991-05-14            2013-04-14
# ...    ...                  ...        ...                   ...
# 18306  NaN         raheem smith 1995-06-28            2013-10-20
# 18307  NaN         raheem smith 1995-06-28            2013-10-20
# 18308  NaN         raheem smith 1995-06-28            2013-10-20
# 18314  NaN  florencia sanmartin 1992-12-18            2014-06-30
# 18315  NaN  florencia sanmartin 1992-12-18            2014-06-30
#
#       c_offense_date     sex  age          age_cat              race  \
# 0         2013-08-13    Male   69  Greater than 45             Other
# 1         2013-08-13    Male   69  Greater than 45             Other
# 4         2013-04-13    Male   24     Less than 25  African-American
# 5         2013-04-13    Male   24     Less than 25  African-American
# 6         2013-04-13    Male   24     Less than 25  African-American
# ...              ...     ...  ...              ...               ...
# 18306     2013-10-19    Male   20     Less than 25  African-American
# 18307     2013-10-19    Male   20     Less than 25  African-American
# 18308     2013-10-19    Male   20     Less than 25  African-American
# 18314     2014-06-28  Female   23     Less than 25          Hispanic
# 18315     2014-06-28  Female   23     Less than 25          Hispanic
#
#       c_charge_degree                 c_charge_desc  days_b_screening_arrest  \
# 0                (F3)  Aggravated Assault w/Firearm                     -1.0
# 1                (F3)  Aggravated Assault w/Firearm                     -1.0
# 4                (F3)         Possession of Cocaine                     -1.0
# 5                (F3)         Possession of Cocaine                     -1.0
# 6                (F3)         Possession of Cocaine                     -1.0
# ...               ...                           ...                      ...
# 18306            (F3)         Possession of Cocaine                     -1.0
# 18307            (F3)         Possession of Cocaine                     -1.0
# 18308            (F3)         Possession of Cocaine                     -1.0
# 18314            (F3)        Possession of Ethylone                     -2.0
# 18315            (F3)        Possession of Ethylone                     -2.0
#
#        decile_score  is_recid r_offense_date  c_case_number  v_decile_score  \
# 0                 1         0            NaT  13011352CF10A               1
# 1                 1         0            NaT  13011352CF10A               1
# 4                 4         1     2013-06-16  13005330CF10A               3
# 5                 4         1     2013-06-16  13005330CF10A               3
# 6                 4         1     2013-06-16  13005330CF10A               3
# ...             ...       ...            ...            ...             ...
# 18306             9         0            NaT  13014650CF10A               9
# 18307             9         0            NaT  13014650CF10A               9
# 18308             9         0            NaT  13014650CF10A               9
# 18314             4         1     2015-03-15  14008895CF10A               4
# 18315             4         1     2015-03-15  14008895CF10A               4
#
#        is_violent_recid vr_offense_date score_text
# 0                     0             NaT        Low
# 1                     0             NaT        Low
# 4                     0             NaT        Low
# 5                     0             NaT        Low
# 6                     0             NaT        Low
# ...                 ...             ...        ...
# 18306                 0             NaT       High
# 18307                 0             NaT       High
# 18308                 0             NaT       High
# 18314                 0             NaT        Low
# 18315                 0             NaT        Low
#
# [11423 rows x 20 columns]

# %% [markdown]
# The data has many multiple duplicates.

# %%
# remove duplication of the same case, every case should be represented one time
analysis_ND=analysis.drop_duplicates(subset='c_case_number',keep='last')
analysis_ND
# Out:
#          id                   name        dob compas_screening_date  \
# 1       2.0       miguel hernandez 1947-04-18            2013-08-14
# 3       4.0            kevon dixon 1982-01-22            2013-01-27
# 8       9.0               ed philo 1991-05-14            2013-04-14
# 9      10.0            marcu brown 1993-01-21            2013-01-13
# 10     11.0     bouthy pierrelouis 1973-01-22            2013-03-26
# ...     ...                    ...        ...                   ...
# 18310   NaN        malcolm simmons 1993-03-25            2014-01-02
# 18311   NaN  alexsandra beauchamps 1984-12-21            2014-12-29
# 18312   NaN        winston gregory 1958-01-10            2014-01-14
# 18313   NaN            farrah jean 1982-11-17            2014-09-03
# 18315   NaN    florencia sanmartin 1992-12-18            2014-06-30
#
#       c_offense_date     sex  age          age_cat              race  \
# 1         2013-08-13    Male   69  Greater than 45             Other
# 3         2013-01-26    Male   34          25 - 45  African-American
# 8         2013-04-13    Male   24     Less than 25  African-American
# 9         2013-12-01    Male   23     Less than 25  African-American
# 10               NaT    Male   43          25 - 45             Other
# ...              ...     ...  ...              ...               ...
# 18310     2014-01-31    Male   23     Less than 25  African-American
# 18311     2014-12-28  Female   31          25 - 45  African-American
# 18312     2014-01-13    Male   57  Greater than 45             Other
# 18313     2014-08-03  Female   33          25 - 45  African-American
# 18315     2014-06-28  Female   23     Less than 25          Hispanic
#
#       c_charge_degree                   c_charge_desc  \
# 1                (F3)    Aggravated Assault w/Firearm
# 3                (F3)  Felony Battery w/Prior Convict
# 8                (F3)           Possession of Cocaine
# 9                (F3)          Possession of Cannabis
# 10               (F7)           arrest case no charge
# ...               ...                             ...
# 18310            (F3)   Leaving the Scene of Accident
# 18311            (M1)                         Battery
# 18312            (F2)   Aggravated Battery / Pregnant
# 18313            (M1)   Battery on Law Enforc Officer
# 18315            (F3)          Possession of Ethylone
#
#        days_b_screening_arrest  decile_score  is_recid r_offense_date  \
# 1                         -1.0             1         0            NaT
# 3                         -1.0             3         1     2013-05-07
# 8                         -1.0             4         1     2013-06-16
# 9                          NaN             8         0            NaT
# 10                         NaN             1         0            NaT
# ...                        ...           ...       ...            ...
# 18310                     -1.0             3         0            NaT
# 18311                     -1.0             6         0            NaT
# 18312                     -1.0             1         0            NaT
# 18313                     -1.0             2         0            NaT
# 18315                     -2.0             4         1     2015-03-15
#
#        c_case_number  v_decile_score  is_violent_recid vr_offense_date  \
# 1      13011352CF10A               1                 0             NaT
# 3      13001275CF10A               1                 1      2013-05-07
# 8      13005330CF10A               3                 0             NaT
# 9      13000570CF10A               6                 0             NaT
# 10     12014130CF10A               1                 0             NaT
# ...              ...             ...               ...             ...
# 18310  14001422CF10A               5                 0             NaT
# 18311  14018106MM10A               4                 0             NaT
# 18312  14000581CF10A               1                 0             NaT
# 18313  14003308CF10A               2                 0             NaT
# 18315  14008895CF10A               4                 0             NaT
#
#       score_text
# 1            Low
# 3            Low
# 8            Low
# 9           High
# 10           Low
# ...          ...
# 18310        Low
# 18311     Medium
# 18312        Low
# 18313        Low
# 18315        Low
#
# [10310 rows x 20 columns]

# %% [markdown]
# after applying drop duplicate, 1123 Rows deleted from the dataset, now I have only 10310 case remaining

# %% [markdown]
# My next step would be prepare my data for analysis

# %% [markdown]
# # 2. Preparing dataset for analysis

# %% [markdown]
# Before starting to prepare my data, I remove both the attributes name and dob

# %%
# Drop the attributes name and dob because they will not impact my study 
analysis_ND = analysis_ND.drop("dob", axis=1)
analysis_ND = analysis_ND.drop("name", axis=1)
analysis_ND
# Out:
#          id compas_screening_date c_offense_date     sex  age  \
# 1       2.0            2013-08-14     2013-08-13    Male   69
# 3       4.0            2013-01-27     2013-01-26    Male   34
# 8       9.0            2013-04-14     2013-04-13    Male   24
# 9      10.0            2013-01-13     2013-12-01    Male   23
# 10     11.0            2013-03-26            NaT    Male   43
# ...     ...                   ...            ...     ...  ...
# 18310   NaN            2014-01-02     2014-01-31    Male   23
# 18311   NaN            2014-12-29     2014-12-28  Female   31
# 18312   NaN            2014-01-14     2014-01-13    Male   57
# 18313   NaN            2014-09-03     2014-08-03  Female   33
# 18315   NaN            2014-06-30     2014-06-28  Female   23
#
#                age_cat              race c_charge_degree  \
# 1      Greater than 45             Other            (F3)
# 3              25 - 45  African-American            (F3)
# 8         Less than 25  African-American            (F3)
# 9         Less than 25  African-American            (F3)
# 10             25 - 45             Other            (F7)
# ...                ...               ...             ...
# 18310     Less than 25  African-American            (F3)
# 18311          25 - 45  African-American            (M1)
# 18312  Greater than 45             Other            (F2)
# 18313          25 - 45  African-American            (M1)
# 18315     Less than 25          Hispanic            (F3)
#
#                         c_charge_desc  days_b_screening_arrest  decile_score  \
# 1        Aggravated Assault w/Firearm                     -1.0             1
# 3      Felony Battery w/Prior Convict                     -1.0             3
# 8               Possession of Cocaine                     -1.0             4
# 9              Possession of Cannabis                      NaN             8
# 10              arrest case no charge                      NaN             1
# ...                               ...                      ...           ...
# 18310   Leaving the Scene of Accident                     -1.0             3
# 18311                         Battery                     -1.0             6
# 18312   Aggravated Battery / Pregnant                     -1.0             1
# 18313   Battery on Law Enforc Officer                     -1.0             2
# 18315          Possession of Ethylone                     -2.0             4
#
#        is_recid r_offense_date  c_case_number  v_decile_score  \
# 1             0            NaT  13011352CF10A               1
# 3             1     2013-05-07  13001275CF10A               1
# 8             1     2013-06-16  13005330CF10A               3
# 9             0            NaT  13000570CF10A               6
# 10            0            NaT  12014130CF10A               1
# ...         ...            ...            ...             ...
# 18310         0            NaT  14001422CF10A               5
# 18311         0            NaT  14018106MM10A               4
# 18312         0            NaT  14000581CF10A               1
# 18313         0            NaT  14003308CF10A               2
# 18315         1     2015-03-15  14008895CF10A               4
#
#        is_violent_recid vr_offense_date score_text
# 1                     0             NaT        Low
# 3                     1      2013-05-07        Low
# 8                     0             NaT        Low
# 9                     0             NaT       High
# 10                    0             NaT        Low
# ...                 ...             ...        ...
# 18310                 0             NaT        Low
# 18311                 0             NaT     Medium
# 18312                 0             NaT        Low
# 18313                 0             NaT        Low
# 18315                 0             NaT        Low
#
# [10310 rows x 18 columns]

# %% [markdown]
# 1. Keep only rows that has a case number and has an id

# %%
# keep only rows with a case number 
analysis_ND = analysis_ND[analysis_ND["c_case_number"] != "NaN"]

# %%
# remove all rows with any NaN and NaT values
#analysis_ND =  analysis_ND.dropna()
analysis_ND = analysis_ND.dropna( how='any', subset=['id'])
analysis_ND
# Out:
#             id compas_screening_date c_offense_date     sex  age  \
# 1          2.0            2013-08-14     2013-08-13    Male   69
# 3          4.0            2013-01-27     2013-01-26    Male   34
# 8          9.0            2013-04-14     2013-04-13    Male   24
# 9         10.0            2013-01-13     2013-12-01    Male   23
# 10        11.0            2013-03-26            NaT    Male   43
# ...        ...                   ...            ...     ...  ...
# 10989  10990.0            2013-03-18     2013-03-17    Male   34
# 10992  10993.0            2013-03-22     2013-03-22    Male   23
# 10994  10995.0            2014-04-28            NaT  Female   31
# 10996  10997.0            2013-08-02     2013-07-02    Male   30
# 10997  10998.0            2014-02-24     2014-02-23    Male   52
#
#                age_cat              race c_charge_degree  \
# 1      Greater than 45             Other            (F3)
# 3              25 - 45  African-American            (F3)
# 8         Less than 25  African-American            (F3)
# 9         Less than 25  African-American            (F3)
# 10             25 - 45             Other            (F7)
# ...                ...               ...             ...
# 10989          25 - 45  African-American            (F3)
# 10992     Less than 25  African-American            (F3)
# 10994          25 - 45  African-American            (F1)
# 10996          25 - 45          Hispanic            (F3)
# 10997  Greater than 45  African-American            (F3)
#
#                           c_charge_desc  days_b_screening_arrest  \
# 1          Aggravated Assault w/Firearm                     -1.0
# 3        Felony Battery w/Prior Convict                     -1.0
# 8                 Possession of Cocaine                     -1.0
# 9                Possession of Cannabis                      NaN
# 10                arrest case no charge                      NaN
# ...                                 ...                      ...
# 10989          Possession Of Alprazolam                     -1.0
# 10992    Poss3,4 Methylenedioxymethcath                      0.0
# 10994             arrest case no charge                     -3.0
# 10996    Poss Unlaw Issue Driver Licenc                      0.0
# 10997  Tampering With Physical Evidence                     -1.0
#
#        decile_score  is_recid r_offense_date  c_case_number  v_decile_score  \
# 1                 1         0            NaT  13011352CF10A               1
# 3                 3         1     2013-05-07  13001275CF10A               1
# 8                 4         1     2013-06-16  13005330CF10A               3
# 9                 8         0            NaT  13000570CF10A               6
# 10                1         0            NaT  12014130CF10A               1
# ...             ...       ...            ...            ...             ...
# 10989             9         1     2013-05-20  13003878CF10A               4
# 10992             9         0            NaT  13004155CF10A               9
# 10994             4         0            NaT  14005707CF10A               5
# 10996             2         1     2014-07-06  13001942CF10A               2
# 10997             1         0            NaT  14002552CF10A               1
#
#        is_violent_recid vr_offense_date score_text
# 1                     0             NaT        Low
# 3                     1      2013-05-07        Low
# 8                     0             NaT        Low
# 9                     0             NaT       High
# 10                    0             NaT        Low
# ...                 ...             ...        ...
# 10989                 1      2013-05-12       High
# 10992                 0             NaT       High
# 10994                 0             NaT        Low
# 10996                 0             NaT        Low
# 10997                 0             NaT        Low
#
# [6204 rows x 18 columns]

# %% [markdown]
# 2. I want explore how long people take to be charge for a crime and see if I can filter my selection for cases

# %%
#Check how long arrested people take to be charged for a crime
analysis_ND["days_b_screening_arrest"].describe()
# Out:
# count    5942.000000
# mean       -0.120498
# std        74.925514
# min      -578.000000
# 25%        -1.000000
# 50%        -1.000000
# 75%        -1.000000
# max      1040.000000
# Name: days_b_screening_arrest, dtype: float64

# %% [markdown]
# More than 75% have less than -1 and with -597 as minimum
# to keep only quality data, we will limit my analysis on crimes charger within 30 days of arrest

# %%
# Keep only crimes charged within 30 days of arrest.
analysis_ND = analysis_ND.loc[(analysis_ND["days_b_screening_arrest"] > -30) & (analysis_ND["days_b_screening_arrest"] <30)]

# %% [markdown]
# 3. Since my purpose is evalute Compass, I will remove all the cases that has the crime after the compass screening

# %%
# Remove cases where the date of crime is after copmas screening
analysis_ND = analysis_ND[analysis_ND["c_offense_date"] < analysis_ND["compas_screening_date"]]

# %% [markdown]
# 4. Now, I will create 3 groups: Age, Race and Score using CategoricalDtype

# %%
# Group 1: Age
grp_age = pd.CategoricalDtype(categories=["Less than 25","25 - 45","Greater than 45"],ordered=True)
analysis_ND["age_cat"] = analysis_ND["age_cat"].astype(grp_age)

# Group 2: Race
grp_race = pd.CategoricalDtype(categories=['African-American','Caucasian','Hispanic',"Other",'Asian',
'Native American'],ordered=True)
analysis_ND["race"] = analysis_ND["race"].astype(grp_race)

# Group 3: Score
grp_score = pd.CategoricalDtype(categories=["Low","Medium","High"],ordered=True)
analysis_ND["score_text"] = analysis_ND["score_text"].astype(grp_score)

# %%
#convert the attributes between "Sex" and "c_charge_degree" to categories with the function astype

for att in ["sex","c_charge_degree"]:
    analysis_ND[att] = analysis_ND[att].astype("category")

# %% [markdown]
# 5. Remove all the rows that has empty value for the attribute score_text

# %%
#remove rows with score text equals NaN 
analysis_ND = analysis_ND[analysis_ND["score_text"] != "NaN"]

# %%
#I will not consider traffic tickets & munipal violations as repeated offense (charge degree equals O)
#analysis_ND = analysis_ND[analysis_ND["c_charge_degree"] != "O"]

# %% [markdown]
# 6. I want to know since when the Compass screening happened for both ordinary and violent offenses (I call both variables 2y_r and 2y_v), to do  that I first substract
# the columns of time, then I assign 3 different values for every case:
#     - 0: the offender didnot commit any crime since 1st arrest
#     - 1: the offender committed a new crime in less than 2 years
#     - 2: the offender committed a new crime after 2 years

# %%
# I will call my function nbr_offenses
def nbr_offenses(att,recid):
   
    # Subtract the columns of time
    analysis_ND["days"] = analysis_ND[att] - analysis_ND["compas_screening_date"]
    
    # Convert the output to an integer by using the .days parameter  
    analysis_ND["days"] = analysis_ND["days"].apply(lambda x:x.days)
    
    # Assign the values 0, 1 and 2 
    analysis_ND["offence"] = np.where(analysis_ND[recid]==0,0,
                np.where((analysis_ND[recid]==1) & (analysis_ND["days"] < 730),1,2))
    
    return analysis_ND["offence"]

# %%
# calcualte both 2y_r and 2y_v
analysis_ND["2y_r"] = nbr_offenses("r_offense_date","is_recid")
analysis_ND["2y_v"] = nbr_offenses("vr_offense_date","is_violent_recid")

# %% [markdown]
# 7. I want to foucs only on offenders who didnot or did repeat crime in less then 2 years, so I will remove Offenders who has 2y_r and 2y_v equals 2

# %%
# remove offenders who committed new ordinary crimes after 2 years
analysis_nd_r = analysis_ND[analysis_ND["2y_r"] !=2].copy()

# remove offenders who committed new violent crimes after 2 years
analysis_nd_v = analysis_ND[analysis_ND["2y_v"] != 2].copy()

# %%
# reset the index to  make it easier for me to work with the dataset 
analysis_nd_r.reset_index(drop=True,inplace=True)
analysis_nd_v.reset_index(drop=True,inplace=True)

# %% [markdown]
# 8. In order to make data extraction easier, I add another 2 new attributes:
#     - <b>Attribute 1 :</b> devide cases in 2 categories based on the score using binary values,
#     so if the score >5, the case category will be 1, if the score is lower than 5 the case category will be 0
#     - <b>Attribute 2 :</b> This attribute will help me know if the prediction of Compass was correct or wrong,
#         so if it is "True", the prediction of Compass was correct, if "False" the prediction was wrong

# %%
#Attribute 1: grouping cases in 2 categories (high score (>=5 and low score <5))
analysis_nd_r["binary_score"] = np.where(analysis_nd_r["decile_score"] >=5,1,0)
analysis_nd_v["binary_v_score"] = np.where(analysis_nd_v["v_decile_score"] >=5,1,0)

# %%
# Attribute 2: if the prediction is correct return True,else return false

# For ordinary offense
analysis_nd_r["prediction_recid"] = analysis_nd_r['is_recid'] == analysis_nd_r["binary_score"]

# For violent offense
analysis_nd_v["prediction_vrecid"] = analysis_nd_v['is_violent_recid'] == analysis_nd_v["binary_v_score"]

# %%
# Index reset 
analysis_nd_r.reset_index(drop=True,inplace=True)
analysis_nd_v.reset_index(drop=True,inplace=True)

# %%
#Checking the new values
analysis_nd_r.head(3)
# Out:
#     id compas_screening_date c_offense_date   sex  age          age_cat  \
# 0  2.0            2013-08-14     2013-08-13  Male   69  Greater than 45
# 1  4.0            2013-01-27     2013-01-26  Male   34          25 - 45
# 2  9.0            2013-04-14     2013-04-13  Male   24     Less than 25
#
#                race c_charge_degree                   c_charge_desc  \
# 0             Other            (F3)    Aggravated Assault w/Firearm
# 1  African-American            (F3)  Felony Battery w/Prior Convict
# 2  African-American            (F3)           Possession of Cocaine
#
#    days_b_screening_arrest  ...  v_decile_score  is_violent_recid  \
# 0                     -1.0  ...               1                 0
# 1                     -1.0  ...               1                 1
# 2                     -1.0  ...               3                 0
#
#   vr_offense_date score_text   days  offence 2y_r 2y_v  binary_score  \
# 0             NaT        Low    NaN        0    0    0             0
# 1      2013-05-07        Low  100.0        1    1    1             0
# 2             NaT        Low    NaN        0    1    0             0
#
#    prediction_recid
# 0              True
# 1             False
# 2             False
#
# [3 rows x 24 columns]

# %%
analysis_nd_v.head(3)
# Out:
#     id compas_screening_date c_offense_date   sex  age          age_cat  \
# 0  2.0            2013-08-14     2013-08-13  Male   69  Greater than 45
# 1  4.0            2013-01-27     2013-01-26  Male   34          25 - 45
# 2  9.0            2013-04-14     2013-04-13  Male   24     Less than 25
#
#                race c_charge_degree                   c_charge_desc  \
# 0             Other            (F3)    Aggravated Assault w/Firearm
# 1  African-American            (F3)  Felony Battery w/Prior Convict
# 2  African-American            (F3)           Possession of Cocaine
#
#    days_b_screening_arrest  ...  v_decile_score  is_violent_recid  \
# 0                     -1.0  ...               1                 0
# 1                     -1.0  ...               1                 1
# 2                     -1.0  ...               3                 0
#
#   vr_offense_date score_text   days  offence 2y_r 2y_v  binary_v_score  \
# 0             NaT        Low    NaN        0    0    0               0
# 1      2013-05-07        Low  100.0        1    1    1               0
# 2             NaT        Low    NaN        0    1    0               0
#
#    prediction_vrecid
# 0               True
# 1              False
# 2               True
#
# [3 rows x 24 columns]

# %% [markdown]
# #### Now my data is ready for the exporatory analysis

# %% [markdown]
# # 3. Data Exploration
# In this step, I will be exploring my data to understand more about: the relationship between the crime, race, gender, age and the frequent commited crimes

# %%
# check data
analysis_nd_r.describe().T
# Out:
#                           count         mean          std    min     25%  \
# id                       3527.0  5511.070031  3171.661078    2.0  2703.0
# age                      3527.0    34.908704    12.090702   18.0    25.0
# days_b_screening_arrest  3527.0    -1.666005     4.413039  -29.0    -1.0
# decile_score             3527.0     4.199036     2.843142   -1.0     2.0
# is_recid                 3527.0     0.322937     0.467665    0.0     0.0
# v_decile_score           3527.0     3.442586     2.444397   -1.0     1.0
# is_violent_recid         3527.0     0.074568     0.262730    0.0     0.0
# days                      263.0   314.019011   250.267909 -218.0   123.5
# offence                  3527.0     0.078537     0.283426    0.0     0.0
# 2y_r                     3527.0     0.322937     0.467665    0.0     0.0
# 2y_v                     3527.0     0.078537     0.283426    0.0     0.0
# binary_score             3527.0     0.410547     0.492003    0.0     0.0
#
#                             50%     75%      max
# id                       5531.0  8284.0  10998.0
# age                        32.0    42.0     96.0
# days_b_screening_arrest    -1.0    -1.0     29.0
# decile_score                4.0     6.0     10.0
# is_recid                    0.0     1.0      1.0
# v_decile_score              3.0     5.0     10.0
# is_violent_recid            0.0     0.0      1.0
# days                      295.0   489.0   1046.0
# offence                     0.0     0.0      2.0
# 2y_r                        0.0     1.0      1.0
# 2y_v                        0.0     0.0      2.0
# binary_score                0.0     1.0      1.0

# %% [markdown]
# As shown in  the table above, from the ordinary 3527 cases:
#    - 75% of the cases assessed by compass got score 6
#    - 75% of the offenders are above 42 years old where 32% are recidivists and 7 % are violent recidivist

# %%
analysis_nd_r.describe(include=["object","category"]).T
# Out:
#                 count unique               top  freq
# sex              3527      2              Male  2791
# age_cat          3527      3           25 - 45  1978
# race             3527      6  African-American  1725
# c_charge_degree  3527     12              (F3)  1907
# c_charge_desc    3526    321           Battery   737
# c_case_number    3527   3527     13011352CF10A     1
# score_text       3523      3               Low  2075

# %% [markdown]
# From the table above, we notice:
#  - One of the most common cases is Battery with charge degree F3 with the main race African Americans
#  - TMost reported cases are from males aging between 25 and 45

# %% [markdown]
# <b> After cleaning data, and preparing it, now I will apply SVM to classify it

# %% [markdown]
# ## 3.1 Explore Race

# %% [markdown]
#  {change me}
#   - th race, when looking at the statistics, we must always keep in mind that there is very little data on Asians and Native Americans (a good idea would be to group them together with Other in a single category to make it more representative).
#
#  - In general, we realize that almost 50% of the cases belong to African Americans and they are also the ones with the highest percentage of recidivism (almost 40% of the cases are African American).
#
#  - This is important because the dataset is not balanced and can be very biased due to the predominance of this ethnic group.

# %%
race_g = analysis_nd_r["race"].value_counts(normalize=True,ascending=False).reset_index()

plt.figure(figsize=(8,4))
sns.barplot(x=race_g["index"],y=race_g["race"],color='#42b7bd')
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("% of cases")
plt.title("% of cases by race")
plt.show(block=False)

# %% [markdown]
#  - 50% of the cases belong to African-Americans, 35% to Caucasian, and the rest is below 1%

# %%
analysis_nd_r.groupby("race",as_index=False)["2y_r"].mean().style.background_gradient(cmap='Reds',axis=0)
# Out:
# <style type="text/css">
# #T_b272e_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b272e_row1_col1 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_b272e_row2_col1 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# #T_b272e_row3_col1 {
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_b272e_row4_col1 {
#   background-color: #fb7a5a;
#   color: #f1f1f1;
# }
# #T_b272e_row5_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b272e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >race</th>
#       <th class="col_heading level0 col1" >2y_r</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b272e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b272e_row0_col0" class="data row0 col0" >African-American</td>
#       <td id="T_b272e_row0_col1" class="data row0 col1" >0.385507</td>
#     </tr>
#     <tr>
#       <th id="T_b272e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b272e_row1_col0" class="data row1 col0" >Caucasian</td>
#       <td id="T_b272e_row1_col1" class="data row1 col1" >0.279376</td>
#     </tr>
#     <tr>
#       <th id="T_b272e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b272e_row2_col0" class="data row2 col0" >Hispanic</td>
#       <td id="T_b272e_row2_col1" class="data row2 col1" >0.231270</td>
#     </tr>
#     <tr>
#       <th id="T_b272e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b272e_row3_col0" class="data row3 col0" >Other</td>
#       <td id="T_b272e_row3_col1" class="data row3 col1" >0.240816</td>
#     </tr>
#     <tr>
#       <th id="T_b272e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b272e_row4_col0" class="data row4 col0" >Asian</td>
#       <td id="T_b272e_row4_col1" class="data row4 col1" >0.173913</td>
#     </tr>
#     <tr>
#       <th id="T_b272e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b272e_row5_col0" class="data row5 col0" >Native American</td>
#       <td id="T_b272e_row5_col1" class="data row5 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  - For Recidivism rate, 39 % of African Americans are recidivist and for Caucasian 28%

# %%
##Obtain percentages by rows with normalize
pd.crosstab(analysis_nd_r["race"],analysis_nd_r["age_cat"],normalize=0).style.background_gradient(cmap='Oranges',axis=1)
# Out:
# <style type="text/css">
# #T_0972a_row0_col0 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_0972a_row0_col1, #T_0972a_row1_col1, #T_0972a_row2_col1, #T_0972a_row3_col1, #T_0972a_row4_col1, #T_0972a_row5_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_0972a_row0_col2, #T_0972a_row1_col0, #T_0972a_row2_col0, #T_0972a_row3_col2, #T_0972a_row4_col0, #T_0972a_row4_col2, #T_0972a_row5_col0 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_0972a_row1_col2 {
#   background-color: #fdb475;
#   color: #000000;
# }
# #T_0972a_row2_col2 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_0972a_row3_col0 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_0972a_row5_col2 {
#   background-color: #fda762;
#   color: #000000;
# }
# </style>
# <table id="T_0972a_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >age_cat</th>
#       <th class="col_heading level0 col0" >Less than 25</th>
#       <th class="col_heading level0 col1" >25 - 45</th>
#       <th class="col_heading level0 col2" >Greater than 45</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0972a_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_0972a_row0_col0" class="data row0 col0" >0.267826</td>
#       <td id="T_0972a_row0_col1" class="data row0 col1" >0.572174</td>
#       <td id="T_0972a_row0_col2" class="data row0 col2" >0.160000</td>
#     </tr>
#     <tr>
#       <th id="T_0972a_level0_row1" class="row_heading level0 row1" >Caucasian</th>
#       <td id="T_0972a_row1_col0" class="data row1 col0" >0.156943</td>
#       <td id="T_0972a_row1_col1" class="data row1 col1" >0.548069</td>
#       <td id="T_0972a_row1_col2" class="data row1 col2" >0.294988</td>
#     </tr>
#     <tr>
#       <th id="T_0972a_level0_row2" class="row_heading level0 row2" >Hispanic</th>
#       <td id="T_0972a_row2_col0" class="data row2 col0" >0.198697</td>
#       <td id="T_0972a_row2_col1" class="data row2 col1" >0.540717</td>
#       <td id="T_0972a_row2_col2" class="data row2 col2" >0.260586</td>
#     </tr>
#     <tr>
#       <th id="T_0972a_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_0972a_row3_col0" class="data row3 col0" >0.220408</td>
#       <td id="T_0972a_row3_col1" class="data row3 col1" >0.567347</td>
#       <td id="T_0972a_row3_col2" class="data row3 col2" >0.212245</td>
#     </tr>
#     <tr>
#       <th id="T_0972a_level0_row4" class="row_heading level0 row4" >Asian</th>
#       <td id="T_0972a_row4_col0" class="data row4 col0" >0.217391</td>
#       <td id="T_0972a_row4_col1" class="data row4 col1" >0.565217</td>
#       <td id="T_0972a_row4_col2" class="data row4 col2" >0.217391</td>
#     </tr>
#     <tr>
#       <th id="T_0972a_level0_row5" class="row_heading level0 row5" >Native American</th>
#       <td id="T_0972a_row5_col0" class="data row5 col0" >0.100000</td>
#       <td id="T_0972a_row5_col1" class="data row5 col1" >0.600000</td>
#       <td id="T_0972a_row5_col2" class="data row5 col2" >0.300000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - From the table above, we notice that the predominant age for the different races is between 25 and 45

# %% [markdown]
# ## 3.2 Explore link between sex and age

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=analysis_nd_r,x="sex",hue="age_cat",palette="Greens_r")
plt.title("Cases by age & sex")
plt.xlabel("")
plt.show(block=False)

# %% [markdown]
# Females are secondary compared to males

# %%
decile_mean_age = analysis_nd_r.groupby("age_cat")["decile_score"].mean().reset_index()
sns.barplot(data=decile_mean_age,x="age_cat",y="decile_score",palette="Greys_r")
plt.ylabel("Decile score mean")
plt.xlabel("")
plt.title("Average decile_score by different age ranges")
plt.show(block=False)

# %% [markdown]
# - There is a correlation between age and decile score, the younger the person, the more penalized is.

# %% [markdown]
# ## 3.3 Type of crime per sex (gender)

# %% [markdown]
# I focus, because of their great variety, only on the 10 most typical.
# Many could be grouped by type of crime (drugs, vehicle, robbery and assault...) to facilitate the study of the data.

# %%
#Top 5 crimes for women
female_crime = analysis_nd_r[analysis_nd_r["sex"]=="Female"]["c_charge_desc"].value_counts(normalize=True,ascending=False)[:5].reset_index()
sns.barplot(data=female_crime,x="c_charge_desc",y="index",palette="Reds_r")
plt.title("Top 5 crimes for females")
plt.ylabel("")
plt.xlabel("Cases percentage")
plt.show(block=False)

# %%
#Top 5 crimes for men
male_crime= analysis_nd_r[analysis_nd_r["sex"]=="Male"]["c_charge_desc"].value_counts(normalize=True,ascending=False)[:5].reset_index()

sns.barplot(data=male_crime,x="c_charge_desc",y="index",palette="Greens_r")
plt.title("Top 5 crimes for females")
plt.ylabel("")
plt.xlabel("percentage of cases")
# so only the graphic appears without any text referring to the object type.
plt.show(block=False)

# %% [markdown]
#  Men and women commit the same top 3 offenses

# %% [markdown]
# ## 3.4 Top offenses by both race and sex

# %%
# Here I only consider the top 5 cases by counting their valuses then filtering with the function isin
top_5_cases = analysis_nd_r["c_charge_desc"].value_counts()[:5].index.tolist()
top_cases = analysis_nd_r[analysis_nd_r["c_charge_desc"].isin(top_5_cases)]

# %% [markdown]
# Lets explore in more depth top crimes by race

# %%
pd.crosstab(index=top_cases["c_charge_desc"],columns=top_cases["race"],normalize=1)\
    .style.background_gradient(cmap='Reds',axis=0)
# Out:
# <style type="text/css">
# #T_dc9d5_row0_col0, #T_dc9d5_row0_col1, #T_dc9d5_row0_col2, #T_dc9d5_row0_col3, #T_dc9d5_row0_col4, #T_dc9d5_row0_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_dc9d5_row1_col0 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_dc9d5_row1_col1, #T_dc9d5_row1_col2, #T_dc9d5_row1_col3, #T_dc9d5_row1_col5, #T_dc9d5_row2_col0, #T_dc9d5_row2_col4, #T_dc9d5_row3_col4, #T_dc9d5_row3_col5, #T_dc9d5_row4_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_dc9d5_row1_col4 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_dc9d5_row2_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_dc9d5_row2_col2, #T_dc9d5_row4_col2 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_dc9d5_row2_col3 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_dc9d5_row2_col5 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_dc9d5_row3_col0 {
#   background-color: #f96044;
#   color: #f1f1f1;
# }
# #T_dc9d5_row3_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_dc9d5_row3_col2 {
#   background-color: #fca486;
#   color: #000000;
# }
# #T_dc9d5_row3_col3 {
#   background-color: #fcbfa7;
#   color: #000000;
# }
# #T_dc9d5_row4_col0 {
#   background-color: #fc9474;
#   color: #000000;
# }
# #T_dc9d5_row4_col1 {
#   background-color: #fcb095;
#   color: #000000;
# }
# #T_dc9d5_row4_col3 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_dc9d5_row4_col4 {
#   background-color: #fcc4ad;
#   color: #000000;
# }
# </style>
# <table id="T_dc9d5_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race</th>
#       <th class="col_heading level0 col0" >African-American</th>
#       <th class="col_heading level0 col1" >Caucasian</th>
#       <th class="col_heading level0 col2" >Hispanic</th>
#       <th class="col_heading level0 col3" >Other</th>
#       <th class="col_heading level0 col4" >Asian</th>
#       <th class="col_heading level0 col5" >Native American</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >c_charge_desc</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc9d5_level0_row0" class="row_heading level0 row0" >Battery</th>
#       <td id="T_dc9d5_row0_col0" class="data row0 col0" >0.422006</td>
#       <td id="T_dc9d5_row0_col1" class="data row0 col1" >0.562500</td>
#       <td id="T_dc9d5_row0_col2" class="data row0 col2" >0.538462</td>
#       <td id="T_dc9d5_row0_col3" class="data row0 col3" >0.658537</td>
#       <td id="T_dc9d5_row0_col4" class="data row0 col4" >0.750000</td>
#       <td id="T_dc9d5_row0_col5" class="data row0 col5" >0.666667</td>
#     </tr>
#     <tr>
#       <th id="T_dc9d5_level0_row1" class="row_heading level0 row1" >Driving While License Revoked</th>
#       <td id="T_dc9d5_row1_col0" class="data row1 col0" >0.094708</td>
#       <td id="T_dc9d5_row1_col1" class="data row1 col1" >0.040323</td>
#       <td id="T_dc9d5_row1_col2" class="data row1 col2" >0.059829</td>
#       <td id="T_dc9d5_row1_col3" class="data row1 col3" >0.040650</td>
#       <td id="T_dc9d5_row1_col4" class="data row1 col4" >0.083333</td>
#       <td id="T_dc9d5_row1_col5" class="data row1 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dc9d5_level0_row2" class="row_heading level0 row2" >Felony Battery (Dom Strang)</th>
#       <td id="T_dc9d5_row2_col0" class="data row2 col0" >0.050139</td>
#       <td id="T_dc9d5_row2_col1" class="data row2 col1" >0.044355</td>
#       <td id="T_dc9d5_row2_col2" class="data row2 col2" >0.094017</td>
#       <td id="T_dc9d5_row2_col3" class="data row2 col3" >0.065041</td>
#       <td id="T_dc9d5_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_dc9d5_row2_col5" class="data row2 col5" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_dc9d5_level0_row3" class="row_heading level0 row3" >Grand Theft in the 3rd Degree</th>
#       <td id="T_dc9d5_row3_col0" class="data row3 col0" >0.245125</td>
#       <td id="T_dc9d5_row3_col1" class="data row3 col1" >0.165323</td>
#       <td id="T_dc9d5_row3_col2" class="data row3 col2" >0.213675</td>
#       <td id="T_dc9d5_row3_col3" class="data row3 col3" >0.186992</td>
#       <td id="T_dc9d5_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_dc9d5_row3_col5" class="data row3 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dc9d5_level0_row4" class="row_heading level0 row4" >Possession of Cocaine</th>
#       <td id="T_dc9d5_row4_col0" class="data row4 col0" >0.188022</td>
#       <td id="T_dc9d5_row4_col1" class="data row4 col1" >0.187500</td>
#       <td id="T_dc9d5_row4_col2" class="data row4 col2" >0.094017</td>
#       <td id="T_dc9d5_row4_col3" class="data row4 col3" >0.048780</td>
#       <td id="T_dc9d5_row4_col4" class="data row4 col4" >0.166667</td>
#       <td id="T_dc9d5_row4_col5" class="data row4 col5" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - We already saw from the previous sections, Battery is top committed crime, but what we know more now is that its is taking the highest % for the different races.
# - For the top cases, we still have the sames result.
# - The exception we see that both Asian and Native American don't have any crimes on the category Driving while Licesne revoked and also no Grand Theft.

# %%
# Recidivism % between race and the type of the case 
pd.pivot_table(data=top_cases,values="2y_r",index="c_charge_desc",columns="race",fill_value=0)\
    .style.background_gradient(cmap='Oranges',axis=1)
# Out:
# <style type="text/css">
# #T_de142_row0_col0, #T_de142_row1_col1, #T_de142_row2_col2, #T_de142_row3_col1, #T_de142_row4_col3, #T_de142_row4_col4 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_de142_row0_col1 {
#   background-color: #d14501;
#   color: #f1f1f1;
# }
# #T_de142_row0_col2 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_de142_row0_col3 {
#   background-color: #fc8b3a;
#   color: #f1f1f1;
# }
# #T_de142_row0_col4 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_de142_row0_col5, #T_de142_row1_col4, #T_de142_row1_col5, #T_de142_row2_col4, #T_de142_row2_col5, #T_de142_row3_col4, #T_de142_row3_col5, #T_de142_row4_col5 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_de142_row1_col0 {
#   background-color: #882a04;
#   color: #f1f1f1;
# }
# #T_de142_row1_col2 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_de142_row1_col3 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_de142_row2_col0 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_de142_row2_col1 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_de142_row2_col3 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_de142_row3_col0 {
#   background-color: #942f03;
#   color: #f1f1f1;
# }
# #T_de142_row3_col2 {
#   background-color: #f36e19;
#   color: #f1f1f1;
# }
# #T_de142_row3_col3 {
#   background-color: #ea5f0e;
#   color: #f1f1f1;
# }
# #T_de142_row4_col0 {
#   background-color: #852904;
#   color: #f1f1f1;
# }
# #T_de142_row4_col1 {
#   background-color: #d84801;
#   color: #f1f1f1;
# }
# #T_de142_row4_col2 {
#   background-color: #fdb170;
#   color: #000000;
# }
# </style>
# <table id="T_de142_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >race</th>
#       <th class="col_heading level0 col0" >African-American</th>
#       <th class="col_heading level0 col1" >Caucasian</th>
#       <th class="col_heading level0 col2" >Hispanic</th>
#       <th class="col_heading level0 col3" >Other</th>
#       <th class="col_heading level0 col4" >Asian</th>
#       <th class="col_heading level0 col5" >Native American</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >c_charge_desc</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_de142_level0_row0" class="row_heading level0 row0" >Battery</th>
#       <td id="T_de142_row0_col0" class="data row0 col0" >0.316832</td>
#       <td id="T_de142_row0_col1" class="data row0 col1" >0.243728</td>
#       <td id="T_de142_row0_col2" class="data row0 col2" >0.174603</td>
#       <td id="T_de142_row0_col3" class="data row0 col3" >0.160494</td>
#       <td id="T_de142_row0_col4" class="data row0 col4" >0.111111</td>
#       <td id="T_de142_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_de142_level0_row1" class="row_heading level0 row1" >Driving While License Revoked</th>
#       <td id="T_de142_row1_col0" class="data row1 col0" >0.485294</td>
#       <td id="T_de142_row1_col1" class="data row1 col1" >0.500000</td>
#       <td id="T_de142_row1_col2" class="data row1 col2" >0.285714</td>
#       <td id="T_de142_row1_col3" class="data row1 col3" >0.200000</td>
#       <td id="T_de142_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_de142_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_de142_level0_row2" class="row_heading level0 row2" >Felony Battery (Dom Strang)</th>
#       <td id="T_de142_row2_col0" class="data row2 col0" >0.222222</td>
#       <td id="T_de142_row2_col1" class="data row2 col1" >0.272727</td>
#       <td id="T_de142_row2_col2" class="data row2 col2" >0.363636</td>
#       <td id="T_de142_row2_col3" class="data row2 col3" >0.125000</td>
#       <td id="T_de142_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_de142_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_de142_level0_row3" class="row_heading level0 row3" >Grand Theft in the 3rd Degree</th>
#       <td id="T_de142_row3_col0" class="data row3 col0" >0.306818</td>
#       <td id="T_de142_row3_col1" class="data row3 col1" >0.329268</td>
#       <td id="T_de142_row3_col2" class="data row3 col2" >0.200000</td>
#       <td id="T_de142_row3_col3" class="data row3 col3" >0.217391</td>
#       <td id="T_de142_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_de142_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_de142_level0_row4" class="row_heading level0 row4" >Possession of Cocaine</th>
#       <td id="T_de142_row4_col0" class="data row4 col0" >0.488889</td>
#       <td id="T_de142_row4_col1" class="data row4 col1" >0.376344</td>
#       <td id="T_de142_row4_col2" class="data row4 col2" >0.181818</td>
#       <td id="T_de142_row4_col3" class="data row4 col3" >0.500000</td>
#       <td id="T_de142_row4_col4" class="data row4 col4" >0.500000</td>
#       <td id="T_de142_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# % of recidivism by crime type
percentage_recid_cases= top_cases.groupby("c_charge_desc")["2y_r"].mean().reset_index().sort_values(by="2y_r",ascending=False)

plt.figure(figsize=(8,4))
sns.barplot(data=percentage_recid_cases,y="c_charge_desc",x="2y_r", color="#7FFFD4")
plt.title(" Recidivism by crime type\n",fontsize=15)
plt.xlabel("")
plt.ylabel("")
plt.axvline(x=0.34,color="#4169E1")
plt.show(block=False)

# %% [markdown]
# ## 4. Check the fairness of the model & how to improve it
#  - I will compare both ordinary & violent offences and see wich one has better accuracy using logisitc linear
#  - I will also see the result by both race and sex

# %%
# first I will calcualte TPR, FPR, FNR, TNR for normal offences
from sklearn.metrics import classification_report
print(classification_report(analysis_nd_r['2y_r'],analysis_nd_r["binary_score"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.68      0.73      2388
#            1       0.48      0.61      0.53      1139
#
#     accuracy                           0.66      3527
#    macro avg       0.63      0.65      0.63      3527
# weighted avg       0.69      0.66      0.67      3527

# %%
# calcualte TPR, FPR, FNR, TNR for normal offences
cross_tab = pd.crosstab(analysis_nd_r["binary_score"],analysis_nd_r['2y_r'],normalize="columns").style.background_gradient(cmap='Reds',axis=1)
cross_tab
# Out:
# <style type="text/css">
# #T_72618_row0_col0, #T_72618_row1_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_72618_row0_col1, #T_72618_row1_col0 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_72618_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >2y_r</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >binary_score</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72618_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72618_row0_col0" class="data row0 col0" >0.683417</td>
#       <td id="T_72618_row0_col1" class="data row0 col1" >0.392450</td>
#     </tr>
#     <tr>
#       <th id="T_72618_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72618_row1_col0" class="data row1 col0" >0.316583</td>
#       <td id="T_72618_row1_col1" class="data row1 col1" >0.607550</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - This model has an accuray of 66%
# - Of the actual positive cases it predicted 61% where it is correct in 48% of the cases => False Positive Rate : 1-0.68 = 0.32
# - Of the actual negative cases, the model predicted 68% of the cases where it was correct for the 78% cases
#   => False Negative Rate 1-0.61=0.39

# %% [markdown]
# Now I check the prediction for violent crimes

# %%
# analysis_nd_v only cases with violent crimes
pd.crosstab(analysis_nd_v["binary_v_score"],analysis_nd_v['2y_v'],normalize="columns").style.background_gradient(cmap='Greens',axis=1)
# Out:
# <style type="text/css">
# #T_baf0d_row0_col0, #T_baf0d_row1_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_baf0d_row0_col1, #T_baf0d_row1_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_baf0d_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >2y_v</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >binary_v_score</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baf0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_baf0d_row0_col0" class="data row0 col0" >0.717326</td>
#       <td id="T_baf0d_row0_col1" class="data row0 col1" >0.469880</td>
#     </tr>
#     <tr>
#       <th id="T_baf0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_baf0d_row1_col0" class="data row1 col0" >0.282674</td>
#       <td id="T_baf0d_row1_col1" class="data row1 col1" >0.530120</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(classification_report(analysis_nd_v['2y_v'],analysis_nd_v["binary_v_score"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.72      0.82      3336
#            1       0.12      0.53      0.20       249
#
#     accuracy                           0.70      3585
#    macro avg       0.54      0.62      0.51      3585
# weighted avg       0.90      0.70      0.78      3585

# %% [markdown]
# The prediction here is worse than the previous one even though the accuracy shows a higher score,
# as we see, the prediction for positive cases is higher compared to the previous one (18% more)

# %%
analysis_nd_v['2y_v'].value_counts(normalize=True)
# Out:
# 0    0.930544
# 1    0.069456
# Name: 2y_v, dtype: float64

# %%
analysis_nd_r["2y_r"].value_counts(normalize=True)
# Out:
# 0    0.677063
# 1    0.322937
# Name: 2y_r, dtype: float64

# %% [markdown]
# - Despite the accuracy being higher (0.70 > 0.66)
# - In case of violent crimes, the model is less accurate for positive cases (diffirence 18% higher)
# - False Positive Rate : 0.46
# - False Negative Rate:  0.28
#
# Conclusion, it shows more accuracy with less accurate predicition for positive cases

# %% [markdown]
# ## 4.1 Check Descrimination of COMPASS for both the race and sex

# %%
# Comparaison between Revidivism &  Compas forcast
reality = analysis_nd_r.groupby("race",as_index=False)["2y_r"].mean()
compas_prediction = analysis_nd_r.groupby("race")["binary_score"].mean().reset_index()

sns.barplot(data=compas_prediction,x="race",y="binary_score",color="powderblue",label="Prediction")

ax= sns.barplot(data=reality,x="race",y="2y_r",color="blue",label="Real")

plt.title("Recidivism rate in reality vs. Compas prediction")
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")
plt.legend()
plt.show(block=False)

# %% [markdown]
# Comparing the reality with the system COMPASS, shows hi less accuray for false positive prediction where the highest % goes for Afriacan american followed by Asians and Native Americans

# %%
analysis_nd_r.groupby("race").agg({"2y_r":"mean",
                                    "binary_score":"mean"}).style.background_gradient(cmap='Greens',axis=1)
# Out:
# <style type="text/css">
# #T_9a611_row0_col0, #T_9a611_row1_col0, #T_9a611_row2_col0, #T_9a611_row3_col1, #T_9a611_row4_col0, #T_9a611_row5_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_9a611_row0_col1, #T_9a611_row1_col1, #T_9a611_row2_col1, #T_9a611_row3_col0, #T_9a611_row4_col1, #T_9a611_row5_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9a611_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >2y_r</th>
#       <th class="col_heading level0 col1" >binary_score</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >race</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a611_level0_row0" class="row_heading level0 row0" >African-American</th>
#       <td id="T_9a611_row0_col0" class="data row0 col0" >0.385507</td>
#       <td id="T_9a611_row0_col1" class="data row0 col1" >0.548986</td>
#     </tr>
#     <tr>
#       <th id="T_9a611_level0_row1" class="row_heading level0 row1" >Caucasian</th>
#       <td id="T_9a611_row1_col0" class="data row1 col0" >0.279376</td>
#       <td id="T_9a611_row1_col1" class="data row1 col1" >0.299918</td>
#     </tr>
#     <tr>
#       <th id="T_9a611_level0_row2" class="row_heading level0 row2" >Hispanic</th>
#       <td id="T_9a611_row2_col0" class="data row2 col0" >0.231270</td>
#       <td id="T_9a611_row2_col1" class="data row2 col1" >0.244300</td>
#     </tr>
#     <tr>
#       <th id="T_9a611_level0_row3" class="row_heading level0 row3" >Other</th>
#       <td id="T_9a611_row3_col0" class="data row3 col0" >0.240816</td>
#       <td id="T_9a611_row3_col1" class="data row3 col1" >0.216327</td>
#     </tr>
#     <tr>
#       <th id="T_9a611_level0_row4" class="row_heading level0 row4" >Asian</th>
#       <td id="T_9a611_row4_col0" class="data row4 col0" >0.173913</td>
#       <td id="T_9a611_row4_col1" class="data row4 col1" >0.304348</td>
#     </tr>
#     <tr>
#       <th id="T_9a611_level0_row5" class="row_heading level0 row5" >Native American</th>
#       <td id="T_9a611_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_9a611_row5_col1" class="data row5 col1" >0.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
race_acc = analysis_nd_r.groupby("race")["prediction_recid"].mean().reset_index()
ax= sns.barplot(data=race_acc,x="race",y="prediction_recid",color="#FED8B1")
plt.title("  COMPASS accuracy rate by race")
plt.xticks(rotation=45)
plt.xlabel("")
plt.ylabel("")
for num,text in zip(range(6),round(race_acc["prediction_recid"],2)):
    ax.text(num,text-0.05,text)

# %%
# Recidivism by gender
prediction_sex = analysis_nd_r.groupby("sex")["binary_score"].mean()
recidivism_sex = analysis_nd_r.groupby("sex")["2y_r"].mean()
comparacion_sex = analysis_nd_r.groupby("sex")["prediction_recid"].mean()

dt_comp_sex_recidivism = pd.concat([prediction_sex,recidivism_sex,comparacion_sex],axis=1).reset_index()
dt_comp_sex_recidivism.columns = ["sex","decile_score","2y_r","accuracy"]
dt_comp_sex_recidivism.round(2).style.background_gradient(cmap='Greens',axis=1)
# Out:
# <style type="text/css">
# #T_d7fa2_row0_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_d7fa2_row0_col2, #T_d7fa2_row1_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_d7fa2_row0_col3, #T_d7fa2_row1_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_d7fa2_row1_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# </style>
# <table id="T_d7fa2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sex</th>
#       <th class="col_heading level0 col1" >decile_score</th>
#       <th class="col_heading level0 col2" >2y_r</th>
#       <th class="col_heading level0 col3" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7fa2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7fa2_row0_col0" class="data row0 col0" >Female</td>
#       <td id="T_d7fa2_row0_col1" class="data row0 col1" >0.360000</td>
#       <td id="T_d7fa2_row0_col2" class="data row0 col2" >0.210000</td>
#       <td id="T_d7fa2_row0_col3" class="data row0 col3" >0.660000</td>
#     </tr>
#     <tr>
#       <th id="T_d7fa2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7fa2_row1_col0" class="data row1 col0" >Male</td>
#       <td id="T_d7fa2_row1_col1" class="data row1 col1" >0.420000</td>
#       <td id="T_d7fa2_row1_col2" class="data row1 col2" >0.350000</td>
#       <td id="T_d7fa2_row1_col3" class="data row1 col3" >0.660000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>If we look into sex, in real world males are more recidivists than females and we see same in compass.

# %% [markdown]
# # 4.2 Percentage of false positives and negative positives

# %%
# Create 2 attributes one for the name and one for the result
def wrong_prediction(att):
    # Build 2 lists one for the FPR and one for FNR
    list_att = []
    FPR = []
    FNR = []
    for x in analysis_nd_r[att].unique().tolist():    
        #Filter by race or gender
        data = analysis_nd_r[analysis_nd_r[att]==x] 
        # create sorting report (with output_dict we return a dictionary)   
        classif_race = classification_report(data['2y_r'],data["binary_score"],output_dict=True)
        list_att.append(x)
        # False Positive Rate is 1-exahusivity(recall)
        false_positive = 1 - classif_race.get("0")["recall"]
        FPR.append(false_positive)
        # False Negative Rate 1-TPR
        false_negative = 1 - classif_race.get("1")["recall"]
        FNR.append(false_negative)
    # creamos dataframe
    df_fpr = pd.DataFrame({x:list_att,"FPR":FPR,"FNR":FNR})
    return df_fpr

# %%
wrong_prediction("race").style.background_gradient(cmap='Oranges',axis=1)
# Out:
# <style type="text/css">
# #T_03a1d_row0_col1, #T_03a1d_row1_col2, #T_03a1d_row2_col1, #T_03a1d_row3_col1, #T_03a1d_row4_col1, #T_03a1d_row5_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_03a1d_row0_col2, #T_03a1d_row1_col1, #T_03a1d_row2_col2, #T_03a1d_row3_col2, #T_03a1d_row4_col2, #T_03a1d_row5_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_03a1d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Native American</th>
#       <th class="col_heading level0 col1" >FPR</th>
#       <th class="col_heading level0 col2" >FNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03a1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03a1d_row0_col0" class="data row0 col0" >Other</td>
#       <td id="T_03a1d_row0_col1" class="data row0 col1" >0.150538</td>
#       <td id="T_03a1d_row0_col2" class="data row0 col2" >0.576271</td>
#     </tr>
#     <tr>
#       <th id="T_03a1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_03a1d_row1_col0" class="data row1 col0" >African-American</td>
#       <td id="T_03a1d_row1_col1" class="data row1 col1" >0.455660</td>
#       <td id="T_03a1d_row1_col2" class="data row1 col2" >0.302256</td>
#     </tr>
#     <tr>
#       <th id="T_03a1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_03a1d_row2_col0" class="data row2 col0" >Caucasian</td>
#       <td id="T_03a1d_row2_col1" class="data row2 col1" >0.220068</td>
#       <td id="T_03a1d_row2_col2" class="data row2 col2" >0.494118</td>
#     </tr>
#     <tr>
#       <th id="T_03a1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_03a1d_row3_col0" class="data row3 col0" >Hispanic</td>
#       <td id="T_03a1d_row3_col1" class="data row3 col1" >0.199153</td>
#       <td id="T_03a1d_row3_col2" class="data row3 col2" >0.605634</td>
#     </tr>
#     <tr>
#       <th id="T_03a1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_03a1d_row4_col0" class="data row4 col0" >Asian</td>
#       <td id="T_03a1d_row4_col1" class="data row4 col1" >0.210526</td>
#       <td id="T_03a1d_row4_col2" class="data row4 col2" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_03a1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_03a1d_row5_col0" class="data row5 col0" >Native American</td>
#       <td id="T_03a1d_row5_col1" class="data row5 col1" >0.100000</td>
#       <td id="T_03a1d_row5_col2" class="data row5 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see clearly in the table above, that the African- American has the highest % of False positive rate compared to the rest of races.
# => <b> This shows clearly the mistreat discrimination

# %%
wrong_prediction("sex").style.background_gradient(cmap='Blues',axis=1)
# Out:
# <style type="text/css">
# #T_133a7_row0_col1, #T_133a7_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_133a7_row0_col2, #T_133a7_row1_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_133a7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Female</th>
#       <th class="col_heading level0 col1" >FPR</th>
#       <th class="col_heading level0 col2" >FNR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_133a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_133a7_row0_col0" class="data row0 col0" >Male</td>
#       <td id="T_133a7_row0_col1" class="data row0 col1" >0.317829</td>
#       <td id="T_133a7_row0_col2" class="data row0 col2" >0.383756</td>
#     </tr>
#     <tr>
#       <th id="T_133a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_133a7_row1_col0" class="data row1 col0" >Female</td>
#       <td id="T_133a7_row1_col1" class="data row1 col1" >0.312715</td>
#       <td id="T_133a7_row1_col2" class="data row1 col2" >0.448052</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For Gender, Recidivism is same for both gender.

# %%
d = analysis_nd_r.groupby(["decile_score","race"]).agg({"2y_r":"mean"}).reset_index()
d = d[d["race"].isin(["African-American","Caucasian"])]
im = sns.scatterplot(data=d,x="decile_score",y="2y_r",hue="race")
im.set(ylim=(0,1))
plt.show(block=False)

# %% [markdown]
# # 4.SUMMARY
# 1. Compas evaluates by race and gender; there are some differences in results, but we must not forget that one of the races has the highest prevalence (nearly 50%) and they are also the most likely to recidivate (nearly 40%).
# 2. Adding the two_year_r feature based on compas report was for the purpose to see if adding this feature will help to narrow the prediction coming from COMPASS
# 3. We saw that is_violent_racid got better compard to is_recid but no improvement on Positive cases prediction it became worse.
# My suggestion, is to remove the race from the full data and train the model in a way that it will be always independant from the race. In that way the discrimination will be avoided, maybe not fully but at least it would be better.

# %% [markdown]
# # 9.References

# %% [markdown]
# kaggle.com. (n.d.). Compas: thoroughly investigating the controversial. [online] Available at: https://www.kaggle.com/code/gonzalogarciafuste/compas-thoroughly-investigating-the-controversial/data [Accessed 25 OCt. 2022].
